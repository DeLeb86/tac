# %% [markdown]
# # Clustering de documents

# %% [markdown]
# ## Imports

# %%
import collections
import os
import string
import sys

import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
from pprint import pprint
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine

# %%
import nltk

nltk.download('punkt')
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Denis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data_path = "../../data/txt/"

# %% [markdown]
# ## Choisir une décennie

# %%
DECADE = '1950'

# %% [markdown]
# ## Charger tous les  fichiers de la décennie et en créer une liste de textes

# %%
files = [f for f in sorted(os.listdir(data_path)) if f"_{DECADE[:-1]}" in f]

# %%
# Exemple de fichiers
files[:5]
# Out:
# ['KB_JB838_1950-01-06_01-00002.txt',
#  'KB_JB838_1950-01-07_01-00013.txt',
#  'KB_JB838_1950-01-08_01-00011.txt',
#  'KB_JB838_1950-01-10_01-00006.txt',
#  'KB_JB838_1950-01-15_01-00010.txt']

# %%
texts = [open(data_path + f, "r", encoding="utf-8").read() for f in files]

# %%
# Exemple de textes
texts[0][:400]
# Out:
# '/ LE SOIR Une importante manifestation franco-belge Le Comité franco-belge du Commerce, de l’Industrie et de l’Agriculture qui. au cours de l’année écoulée et dans les circonstances les plus difficiles a rendu aux relations économiques entre les deux pays des services considérables, donnera le 12 janvier, à 19 h. 30, un dîner à l’occasion de l’anniversaire de son installation. Ce comité, qui fonct'

# %% [markdown]
# ## Vectoriser les documents à l'aide de TF-IDF

# %%
# Création d'une fonction de pré-traitement
def preprocessing(text, stem=True):
    """ Tokenize text and remove punctuation """
    text = text.translate(string.punctuation)
    tokens = word_tokenize(text)
    return tokens

# %% [markdown]
# ### Instancier le modèle TF-IDF avec ses arguments

# %%
vectorizer = TfidfVectorizer(
    tokenizer=preprocessing,
    stop_words=stopwords.words('french'),
    max_df=0.5,
    min_df=0.1,
    lowercase=True)

# %% [markdown]
# ### Construire la matrice de vecteurs à l'aide de la fonction `fit_transform`

# %%
tfidf_vectors = vectorizer.fit_transform(texts)
# Out:
# c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tfidf_vectors = vectorizer.fit_transform(texts)
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\feature_extraction\text.py:2091, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2084 self._check_params()
#    2085 self._tfidf = TfidfTransformer(
#    2086     norm=self.norm,
#    2087     use_idf=self.use_idf,
#    2088     smooth_idf=self.smooth_idf,
#    2089     sublinear_tf=self.sublinear_tf,
#    2090 )
# -> 2091 X = super().fit_transform(raw_documents)
#    2092 self._tfidf.fit(X)
#    2093 # X is already a transformed view of raw_documents so
#    2094 # we set copy to False
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\feature_extraction\text.py:1259, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1257 for doc in raw_documents:
#    1258     feature_counter = {}
# -> 1259     for feature in analyze(doc):
#    1260         try:
#    1261             feature_idx = vocabulary[feature]
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\sklearn\feature_extraction\text.py:110, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     108     doc = preprocessor(doc)
#     109 if tokenizer is not None:
# --> 110     doc = tokenizer(doc)
#     111 if ngrams is not None:
#     112     if stop_words is not None:
#
# Cell In[13], line 5, in preprocessing(text, stem)
#       3 """ Tokenize text and remove punctuation """
#       4 text = text.translate(string.punctuation)
# ----> 5 tokens = word_tokenize(text)
#       6 return tokens
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = PunktTokenizer(language)
#     107     return tokenizer.tokenize(text)
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\nltk\tokenize\punkt.py:1744, in PunktTokenizer.__init__(self, lang)
#    1742 def __init__(self, lang="english"):
#    1743     PunktSentenceTokenizer.__init__(self)
# -> 1744     self.load_lang(lang)
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\nltk\tokenize\punkt.py:1749, in PunktTokenizer.load_lang(self, lang)
#    1746 def load_lang(self, lang="english"):
#    1747     from nltk.data import find
# -> 1749     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750     self._params = load_punkt_params(lang_dir)
#    1751     self._lang = lang
#
# File c:\Users\Denis\Workspace\ULB\tac\.venv311\Lib\site-packages\nltk\data.py:582, in find(resource_name, paths)
#     580 sep = "*" * 70
#     581 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 582 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\Denis/nltk_data'
#     - 'c:\\Users\\Denis\\Workspace\\ULB\\tac\\.venv311\\nltk_data'
#     - 'c:\\Users\\Denis\\Workspace\\ULB\\tac\\.venv311\\share\\nltk_data'
#     - 'c:\\Users\\Denis\\Workspace\\ULB\\tac\\.venv311\\lib\\nltk_data'
#     - 'C:\\Users\\Denis\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
# Détail de la matrice
tfidf_vectors

# %% [markdown]
# ### Imprimer le vecteur tf-IDF du premier document

# %%
pd.Series(
    tfidf_vectors[0].toarray()[0],
    index=vectorizer.get_feature_names_out()
    ).sort_values(ascending=False)

# %% [markdown]
# ## Comprendre les vecteurs et leurs "distances"

# %%
cosine([1, 2, 3], [1, 2, 3])

# %%
cosine([1, 2, 3], [1, 2, 2])

# %%
cosine([1, 2, 3], [2, 2, 2])

# %% [markdown]
# ### Tests sur nos documents

# %%
tfidf_array = tfidf_vectors.toarray()

# %%
# Vecteur du document 0
tfidf_array[0]

# %%
# Vecteur du document 1
tfidf_array[1]

# %%
cosine(tfidf_array[0], tfidf_array[1])

# %% [markdown]
# ## Appliquer un algorithme de clustering sur les vecteurs TF-IDF des documents

# %% [markdown]
# Pour en savoir plus sur le KMeans clustering :
# - https://medium.com/dataseries/k-means-clustering-explained-visually-in-5-minutes-b900cc69d175

# %% [markdown]
# ### Définir un nombre de clusters

# %%
N_CLUSTERS = 5

# %% [markdown]
# ### Instancier le modèle K-Means et ses arguments

# %%
km_model = KMeans(n_clusters=N_CLUSTERS)

# %% [markdown]
# ### Appliquer le clustering à l'aide de la fonction `fit_predict`

# %%
clusters = km_model.fit_predict(tfidf_vectors)

# %%
clustering = collections.defaultdict(list)

for idx, label in enumerate(clusters):
    clustering[label].append(files[idx])

# %%
pprint(dict(clustering))

# %% [markdown]
# ## Visualiser les clusters

# %% [markdown]
# ### Réduire les vecteurs à 2 dimensions à l'aide de l'algorithme PCA
# Cette étape est nécessaire afin de visualiser les documents dans un espace 2D
#
# https://fr.wikipedia.org/wiki/Analyse_en_composantes_principales

# %%
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(tfidf_vectors.toarray())

# %%
reduced_vectors[:10]

# %% [markdown]
# ### Générer le plot

# %%
x_axis = reduced_vectors[:, 0]
y_axis = reduced_vectors[:, 1]

plt.figure(figsize=(10,10))
scatter = plt.scatter(x_axis, y_axis, s=100, c=clusters)

# Ajouter les centroïdes
centroids = pca.transform(km_model.cluster_centers_)
plt.scatter(centroids[:, 0], centroids[:, 1],  marker = "x", s=100, linewidths = 2, color='black')

# Ajouter la légende
plt.legend(handles=scatter.legend_elements()[0], labels=set(clusters), title="Clusters")
